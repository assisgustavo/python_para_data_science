# %% [markdown]
# <a href="https://colab.research.google.com/github/assisgustavo/python_para_data_science/blob/main/python_para_data_science/python_para_data_science/L%C3%B3gica_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lógica de programação com Python

# %%
1+1
# Out:
# 2

# %%
'Gustavo'
# Out:
# 'Gustavo'

# %%
nome = 'Gustavo'

# %%
nome
# Out:
# 'Gustavo'

# %%
idade = 27

# %%
idade
# Out:
# 27

# %%
print('O nome é', nome, 'e a idade é', idade, )
# Out:
# O nome é Gustavo e a idade é 27

# %% [markdown]
# # Criando minha primeira função

# %%
def saudacao ():
  nome = input('Qual o seu nome: ')
  print('Olá', nome,)

# %%
saudacao()
# Out:
# Qual o seu nome: Gustavo
# Olá Gustavo

# %% [markdown]
# # Parametros

# %%
nome = 'Luiza'

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Olá {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Olá Luiza

# %% [markdown]
# # Condicional

# %%
idade = 10
def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print('Você pode dirigir')
  else:
    print('Você não pode dirigir')

# %%
verifica_se_pode_dirigir(idade)
# Out:
# Você não pode dirigir

# %% [markdown]
# # Convertendo str para int

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade_str = input('Digite a sua idade: ')
  idade = int(idade_str)
  if idade >=18:
    print('Você pode dirigir')
  else:
    print('Você não pode dirigir')

# %%
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Digite a sua idade: 27
# Você pode dirigir

# %% [markdown]
# # Criando uma Lista

# %%
idade = 27

# %%
type(idade)
# Out:
# int

# %%
idades = [18, 23, 25, 50]
#         0    1  2   3
#         0   -3 -2  -1  
type(idades)
# Out:
# list

# %%
idades[3]
# Out:
# 50

# %%
idades[0:3]
# Out:
# [18, 23, 25]

# %%
idades[0:]
# Out:
# [18, 23, 25, 50]

# %% [markdown]
# # Laços e Loops

# %%
idades
# Out:
# [18, 23, 25, 50]

# %%
#for fora da função

def verificando_se_pode_dirigir(idade):
  if idade >= 18:
    print(idade, 'anos de idade, Pode dirigir')
  else:
    print(idade, 'anos de idadade, Não pode dirigir')

for idade in idades:
  verificando_se_pode_dirigir(idade)
# Out:
# 18 anos de idade, Pode dirigir
# 23 anos de idade, Pode dirigir
# 25 anos de idade, Pode dirigir
# 50 anos de idade, Pode dirigir

# %%
#for dentro da função

def verifica_se_pode_dirigir(idade):
  for idade in idades:
    if idade >= 18:
      print(idade, 'anos de idade, você pode dirigir')
    else:
      print(idade, 'anos de idade, você não pode dirigir')
verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade, você pode dirigir
# 23 anos de idade, você pode dirigir
# 25 anos de idade, você pode dirigir
# 50 anos de idade, você pode dirigir

# %% [markdown]
# # Booleano

# %%
idade = 18

# %%
idade >= 18
# Out:
# True

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
permissoes = []

# %%
idades = [20, 14, 40]

# %%
def verifica_se_pode_dirigir(permissoes, idades):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)
verifica_se_pode_dirigir(permissoes, idades)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('Pode dirigir')
  else:
    print('Não pode dirigir')
# Out:
# Pode dirigir
# Não pode dirigir
# Pode dirigir

# %%
idades = [14, 16, 18, 20]

def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18:
      print('Tem permissão')
    else:
      print('Não tem permissão')

# %%
verifica_se_pode_dirigir(idades)
# Out:
# Não tem permissão
# Não tem permissão
# Tem permissão
# Tem permissão

# %% [markdown]
# Exercicio alura

# %%
frase_alura = [' Digitais', 'e ', 'Negócios ', 'de ', 'Tecnologia ', 'Cursos ']
#                   0         1       2         3         4             5
#                   0         -5     -4        -3        -2             -1
# Cursos de técnologia e negócios digitais
# -1, -3, -2, -5, -4, 0
#  5, 3, 4, 1, 2, 0
type(frase_alura)
# Out:
# list

# %%
frase_alura[2]
# Out:
# 'Negócios '

# %%
frase_alura[-3]
# Out:
# 'de '

# %% [markdown]
# # Tipos em uma lista

# %%
lista = ['Gustavo', 27, '18', True]

# %%
for elemento in lista:
  print('O elemento', elemento, 'é do tipo: ', type(elemento))
# Out:
# O elemento Gustavo é do tipo:  <class 'str'>
# O elemento 27 é do tipo:  <class 'int'>
# O elemento 18 é do tipo:  <class 'str'>
# O elemento True é do tipo:  <class 'bool'>

# %% [markdown]
# # Import library random

# %%
from random import randrange
from random import seed
seed(11)
randrange(0, 11)
# Out:
# 7

# %%
notas_matematica = []

# %%
for notas in range(8):
  notas_matematica.append(randrange(0,11))
notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # Import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
y = notas_matematica

# %%
y
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
plt.plot(x, y)

# %%
plt.title('Notas de Matemática')
# Out:
# Text(0.5, 1.0, 'Notas de Matemática')

# %%
plt.plot(x, y)
plt.title('Notas de Matemática')
# Out:
# Text(0.5, 1.0, 'Notas de Matemática')

# %%
plt.plot(x, y)
plt.title('Notas de Matemática')
plt.show()

# %%
plt.plot(x, y)
plt.title('Notas de Matemática')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
plt.plot(x, y)
plt.plot(x, y, marker='o')
plt.title('Notas de Matemática')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
import matplotlib.pyplot as plt

notas_matematica = ['Matemática',8,7,6,6,7,7,8,10]
notas_portugues = ['Português',9,9,9,8,5,6,8,5]
notas_geografia = ['Geografia',10,10,6,7,7,7,8,7]

notas = [notas_matematica, notas_portugues, notas_geografia]

# %%
type(notas_matematica)
# Out:
# list

# %%
type(notas)
# Out:
# list

# %%
for nota in notas:
 x = list(range(1, 9))
 y = nota[1:]
 plt.plot(x, y, marker='o')
 plt.xlabel('Provas')
 plt.ylabel('Notas')
 plt.title(nota[0])
 plt.show()
